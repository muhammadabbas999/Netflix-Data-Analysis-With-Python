# %% [markdown]
# ## Import Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sc

# %% [markdown]
# ## Import Dataset

# %%
# pd.set_option('Display.max_columns',None)
# pd.set_option('Display.width',None)
# pd.set_option('Display.max_rows',None)

ds=pd.read_csv("netflix.csv")

# %%
ds
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8      NaN                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8786   s8797      NaN                        Yunus Emre        Not Given
# 8787   s8798      NaN                         Zak Storm        Not Given
# 8788   s8801      NaN                Zindagi Gulzar Hai        Not Given
# 8789   s8784  TV Show                              Yoko        Not Given
# 8790   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %% [markdown]
# ## Some Basics Information About Dataset

# %% [markdown]
# ### Head()

# %%
ds.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8      NaN                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021        2020.0  PG-13    90 min
# 1         France  9/24/2021        2021.0  TV-MA  1 Season
# 2  United States  9/24/2021        2021.0  TV-MA  1 Season
# 3         Brazil  9/22/2021        2021.0  TV-PG    91 min
# 4  United States  9/24/2021        1993.0  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %% [markdown]
# ### Tail()

# %%
ds.tail()
# Out:
#      show_id     type               title   director        country  \
# 8786   s8797      NaN          Yunus Emre  Not Given         Turkey
# 8787   s8798      NaN           Zak Storm  Not Given  United States
# 8788   s8801      NaN  Zindagi Gulzar Hai  Not Given       Pakistan
# 8789   s8784  TV Show                Yoko  Not Given       Pakistan
# 8790   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8786   1/17/2017        2016.0  TV-PG  2 Seasons
# 8787   9/13/2018           NaN  TV-Y7  3 Seasons
# 8788  12/15/2016        2012.0  TV-PG   1 Season
# 8789   6/23/2018        2016.0   TV-Y   1 Season
# 8790    6/7/2018        2016.0  TV-Y7   1 Season
#
#                                               listed_in
# 8786                  International TV Shows, TV Dramas
# 8787                                           Kids' TV
# 8788  International TV Shows, Romantic TV Shows, TV ...
# ...

# %% [markdown]
# ### Shape

# %%
ds.shape
# Out:
# (8791, 10)

# %% [markdown]
# ### Size

# %%
ds.size
# Out:
# 87910

# %% [markdown]
# ### Columns

# %%
ds.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %% [markdown]
# ### dtypes

# %%
ds.dtypes
# Out:
# show_id          object
# type             object
# title            object
# director         object
# country          object
# date_added       object
# release_year    float64
# rating           object
# duration         object
# listed_in        object
# dtype: object

# %% [markdown]
# ### Info()

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8791 entries, 0 to 8790
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8791 non-null   object
#  1   type          8775 non-null   object
#  2   title         8790 non-null   object
#  3   director      8782 non-null   object
#  4   country       8791 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8784 non-null   float64
#  7   rating        8789 non-null   object
#  8   duration      8791 non-null   object
#  9   listed_in     8791 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 686.9+ KB

# %% [markdown]
# ### Now Check The Dublicates Values In Datasets

# %%
ds.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 8786    False
# 8787    False
# 8788    False
# 8789    False
# 8790    False
# Length: 8791, dtype: bool

# %%
ds[ds.duplicated()]
# Out:
# Empty DataFrame
# Columns: [show_id, type, title, director, country, date_added, release_year, rating, duration, listed_in]
# Index: []

# %% [markdown]
# ### Check The Null Values In Datasets

# %%
ds.isnull()
# Out:
#       show_id   type  title  director  country  date_added  release_year  \
# 0       False  False  False     False    False       False         False
# 1       False  False  False     False    False       False         False
# 2       False  False  False     False    False       False         False
# 3       False  False  False     False    False       False         False
# 4       False   True  False     False    False       False         False
# ...       ...    ...    ...       ...      ...         ...           ...
# 8786    False   True  False     False    False       False         False
# 8787    False   True  False     False    False       False          True
# 8788    False   True  False     False    False       False         False
# 8789    False  False  False     False    False       False         False
# 8790    False  False  False     False    False       False         False
#
#       rating  duration  listed_in
# 0      False     False      False
# ...

# %%
ds.isnull().sum()
# Out:
# show_id          0
# type            16
# title            1
# director         9
# country          0
# date_added       1
# release_year     7
# rating           2
# duration         0
# listed_in        0
# dtype: int64

# %% [markdown]
# ### Using Of HeatMap To Show Null Values

# %%
sc.heatmap(ds.isnull())
# Out:
# <Axes: >

# %% [markdown]
# ### Show that the 'Rumble' movie is given or not also show the it's Show_id and director name

# %%
ds[ds['title'].isin(['Rumble'])]
# Out:
#      show_id   type   title          director country date_added  \
# 5785   s7900  Movie  Rumble  R. Ellis Frazier  Mexico  9/15/2017
#
#       release_year rating duration                               listed_in
# 5785        2016.0  TV-MA   92 min  Action & Adventure, Independent Movies

# %% [markdown]
# ### Show that the in which year highest number of movies and tv shows released

# %%
ds['release_y']=pd.to_datetime(ds['date_added'])

# %%
ds.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8      NaN                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021        2020.0  PG-13    90 min
# 1         France  9/24/2021        2021.0  TV-MA  1 Season
# 2  United States  9/24/2021        2021.0  TV-MA  1 Season
# 3         Brazil  9/22/2021        2021.0  TV-PG    91 min
# 4  United States  9/24/2021        1993.0  TV-MA   125 min
#
#                                            listed_in  release_y
# 0                                      Documentaries 2021-09-25
# ...

# %%
ds['release_y'].dt.year.value_counts()
# Out:
# release_y
# 2019.0    2016
# 2020.0    1879
# 2018.0    1648
# 2021.0    1498
# 2017.0    1185
# 2016.0     426
# 2015.0      82
# 2014.0      24
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: count, dtype: int64

# %% [markdown]
# ### Show In Bar Graph

# %%
clr=['y','b','g','r','k','y','gray','orange','g','y']

# %%
ds['release_y'].dt.year.value_counts().plot(kind="bar",color=clr)
# Out:
# <Axes: xlabel='release_y'>

# %% [markdown]
# ### Show That How Many Movies And TV shows in DataSets

# %%
ds.groupby("type").type.count()
# Out:
# type
# Movie      6116
# TV Show    2659
# Name: type, dtype: int64

# %%
ds.groupby("type").type.count().plot(kind="bar",color=['y','r'])
# Out:
# <Axes: xlabel='type'>

# %% [markdown]
# ### Check The Movies In Randomly Year

# %%
ds['years']=ds['release_y'].dt.year

# %%
ds[(ds['type']=="Movie") & (ds['years']==2021)]
# Out:
#      show_id   type                                     title  \
# 0         s1  Movie                      Dick Johnson Is Dead
# 3        s14  Movie          Confessions of an Invisible Girl
# 6        s10  Movie                              The Starling
# 7       s939  Movie           Motu Patlu in the Game of Zones
# 8        s13  Movie                              Je Suis Karl
# ...      ...    ...                                       ...
# 6827   s1162  Movie  Elizabeth and Margaret: Love and Loyalty
# 6863   s1288  Movie      Fate: The Winx Saga - The Afterparty
# 6907   s1426  Movie               Creating The Queen's Gambit
# 6911   s1432  Movie                               Stuck Apart
# 6923   s1467  Movie              The Minimalists: Less Is Now
#
#                  director         country date_added  release_year rating  \
# 0         Kirsten Johnson   United States  9/25/2021        2020.0  PG-13
# ...

# %% [markdown]
# ### Show The All Movies which is released in Pakistan

# %%
ds[(ds['type'] == "Movie") & (ds["country"] == 'Pakistan')]
# Out:
#      show_id   type                                              title  \
# 12      s852  Movie                                   99 Songs (Tamil)
# 67     s1093  Movie                  Dolly Parton: A MusiCares Tribute
# 111     s405  Movie                      9to5: The Story of a Movement
# 127     s642  Movie                                   Sisters on Track
# 152     s718  Movie                        Headspace: Unwind Your Mind
# ...      ...    ...                                                ...
# 7933   s4535  Movie                      Super Monsters Save Halloween
# 8290   s5787  Movie  Karol Modzelewski, Łukasz „Lotek” Lodkowski No...
# 8326   s5920  Movie                     Iliza Shlesinger: Freezing Hot
# 8525   s7117  Movie                             Jake's Buccaneer Blast
# 8526   s7139  Movie                      John Mellencamp: Plain Spoken
#
#        director   country date_added  release_year rating duration  \
# ...

# %%
ds[(ds['type'] == "Movie") & (ds["country"] == 'Pakistan')]['title']
# Out:
# 12                                       99 Songs (Tamil)
# 67                      Dolly Parton: A MusiCares Tribute
# 111                         9to5: The Story of a Movement
# 127                                      Sisters on Track
# 152                           Headspace: Unwind Your Mind
#                               ...
# 7933                        Super Monsters Save Halloween
# 8290    Karol Modzelewski, Łukasz „Lotek” Lodkowski No...
# 8326                       Iliza Shlesinger: Freezing Hot
# 8525                               Jake's Buccaneer Blast
# 8526                        John Mellencamp: Plain Spoken
# Name: title, Length: 71, dtype: object

# %% [markdown]
# ### Top 10 Directors Which Gives The Highest Movies And TV Shows to the NetFlix

# %%
ds['director'].value_counts().head(10)
# Out:
# director
# Not Given                 2579
# Rajiv Chilaka               20
# Raúl Campos, Jan Suter      18
# Alastair Fothergill         18
# Marcus Raboy                16
# Suhas Kadav                 16
# Jay Karas                   14
# Cathy Garcia-Molina         13
# Jay Chapman                 12
# Martin Scorsese             12
# Name: count, dtype: int64

# %%
ds['director'].value_counts().head(10).plot(kind='bar',color='y')
# Out:
# <Axes: xlabel='director'>

# %% [markdown]
# ### Show Those Movies Which Are Comedians & Country Is United States

# %%
ds[(ds['type']=="Movie") & (ds["listed_in"]=="Comedies")  & (ds["country"]=="Pakistan")]
# Out:
#      show_id   type                                      title   director  \
# 184    s1029  Movie  Dad Stop Embarrassing Me - The Afterparty  Not Given
# 6780    s889  Movie               The Upshaws - The Afterparty  Not Given
#
#        country date_added  release_year rating duration listed_in  release_y  \
# 184   Pakistan  4/16/2021        2021.0  TV-14   37 min  Comedies 2021-04-16
# 6780  Pakistan  5/14/2021        2021.0  TV-14   32 min  Comedies 2021-05-14
#
#        years
# 184   2021.0
# 6780  2021.0

# %% [markdown]
# ### Which Country Has The Highest Number Of TV Shows

# %%
ds.head()
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8      NaN                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021        2020.0  PG-13    90 min
# 1         France  9/24/2021        2021.0  TV-MA  1 Season
# 2  United States  9/24/2021        2021.0  TV-MA  1 Season
# 3         Brazil  9/22/2021        2021.0  TV-PG    91 min
# 4  United States  9/24/2021        1993.0  TV-MA   125 min
#
#                                            listed_in  release_y   years
# 0                                      Documentaries 2021-09-25  2021.0
# ...

# %%
ds_tvshow=ds[ds["type"] == "TV Show"]

# %%
ds_tvshow.head(5)
# Out:
#    show_id     type                            title         director  \
# 1       s3  TV Show                        Ganglands  Julien Leclercq
# 2       s6  TV Show                    Midnight Mass    Mike Flanagan
# 5       s9  TV Show    The Great British Baking Show  Andy Devonshire
# 17      s4  TV Show            Jailbirds New Orleans        Not Given
# 18     s15  TV Show  Crime Stories: India Detectives        Not Given
#
#            country date_added  release_year rating   duration  \
# 1           France  9/24/2021        2021.0  TV-MA   1 Season
# 2    United States  9/24/2021        2021.0  TV-MA   1 Season
# 5   United Kingdom  9/24/2021        2021.0  TV-14  9 Seasons
# 17        Pakistan  9/24/2021        2021.0  TV-MA   1 Season
# 18        Pakistan  9/22/2021        2021.0  TV-MA   1 Season
#
#                                             listed_in  release_y   years
# 1   Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021.0
# ...

# %%
ds_tvshow.country.value_counts().head(10)
# Out:
# country
# United States     844
# Pakistan          346
# United Kingdom    251
# Japan             172
# South Korea       165
# Canada             84
# India              81
# Taiwan             71
# France             65
# Australia          53
# Name: count, dtype: int64

# %%
ds_tvshow.country.value_counts().head(10).plot(kind="bar",color=['y','g','r','b','b','b','y','g'])
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# ### Sort The Values By Years

# %%
ds.sort_values(by="years").head(10)
# Out:
#      show_id     type                        title  \
# 8424   s6612  TV Show              Dinner for Five
# 4254   s5958    Movie         To and From New York
# 4253   s5957    Movie      Just Another Love Story
# 4252   s5956    Movie                     Splatter
# 5382   s7371    Movie  Mad Ron's Prevues from Hell
# 4246   s5950    Movie           Too Young the Hero
# 4251   s5955    Movie                Even the Rain
# 4250   s5954    Movie       Joseph: King of Dreams
# 4249   s5953    Movie             Victim of Beauty
# 4248   s5952    Movie             Unspeakable Acts
#
#                            director        country  date_added  release_year  \
# 8424                      Not Given  United States    2/4/2008        2007.0
# 4254           Sorin Dan Mihalcescu  United States    1/1/2008        2006.0
# 4253                   Ole Bornedal        Denmark    5/5/2009        2007.0
# 4252                      Joe Dante  United States  11/18/2009        2009.0
# ...

# %% [markdown]
# ### What Are The Different Rating Which Is Define By The NetFlix

# %%
ds.rating.nunique()
# Out:
# 14

# %%
ds.rating.unique()
# Out:
# array(['PG-13', 'TV-MA', 'TV-PG', 'TV-14', 'TV-Y7', nan, 'TV-Y', 'PG',
#        'TV-G', 'R', 'G', 'NC-17', 'NR', 'TV-Y7-FV', 'UR'], dtype=object)

# %% [markdown]
# ### How Many Movies Got The TV-14 Rating In Pakistan

# %%
ds[(ds["type"] == "Movie") & (ds["rating"] == "TV-14") & (ds["country"] == "Pakistan")].shape
# Out:
# (19, 12)

# %% [markdown]
# ### How Many Movies Got The TV-14 Rating after 2020

# %%
ds[(ds["type"] == "Movie") & (ds["rating"] == "TV-14") & (ds["years"] > 2020)]
# Out:
#      show_id   type                                 title  \
# 12      s852  Movie                      99 Songs (Tamil)
# 13      s471  Movie           Bridgerton - The Afterparty
# 16      s913  Movie           The Circle - The Afterparty
# 30       s25  Movie                                 Jeans
# 53       s19  Movie                             Intrusion
# ...      ...    ...                                   ...
# 6785    s976  Movie      Shadow and Bone - The Afterparty
# 6790   s1012  Movie                          Free to Play
# 6863   s1288  Movie  Fate: The Winx Saga - The Afterparty
# 6907   s1426  Movie           Creating The Queen's Gambit
# 6923   s1467  Movie          The Minimalists: Less Is Now
#
#                              director         country date_added  \
# 12                          Not Given        Pakistan  5/21/2021
# 13    Krysia Plonka, Kristian Mercado   United States  7/13/2021
# 16    Krysia Plonka, Kristian Mercado   United States   5/7/2021
# ...

# %% [markdown]
# ### Which Movie/TV Shows On Netflix Have Maximum Duration Time

# %%
ds["duration"].unique()
# Out:
# array(['90 min', '1 Season', '91 min', '125 min', '9 Seasons', '104 min',
#        '87 min', '127 min', '76 min', '71 min', '131 min', '39 min',
#        '36 min', '34 min', '35 min', '46 min', '67 min', '65 min',
#        '61 min', '166 min', '103 min', '97 min', '106 min', '2 Seasons',
#        '4 Seasons', '147 min', '94 min', '161 min', '111 min', '110 min',
#        '105 min', '96 min', '124 min', '116 min', '98 min', '115 min',
#        '122 min', '55 min', '99 min', '88 min', '100 min', '6 Seasons',
#        '3 Seasons', '23 min', '102 min', '93 min', '95 min', '85 min',
#        '83 min', '182 min', '5 Seasons', '92 min', '84 min', '48 min',
#        '145 min', '119 min', '80 min', '128 min', '143 min', '273 min',
#        '117 min', '114 min', '118 min', '108 min', '37 min', '121 min',
#        '63 min', '142 min', '113 min', '154 min', '120 min', '82 min',
#        '109 min', '101 min', '86 min', '77 min', '229 min', '15 min',
# ...

# %%
ds[["Minute","Unit"]]=ds["duration"].str.split(" ",expand=True)

# %%
ds.head(2)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021        2020.0  PG-13    90 min
# 1  9/24/2021        2021.0  TV-MA  1 Season
#
#                                            listed_in  release_y   years  \
# 0                                      Documentaries 2021-09-25  2021.0
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021.0
#
#   Minute    Unit
# 0     90     min
# 1      1  Season

# %%
ds['Minute'].max()
# Out:
# '99'

# %%
ds['Minute'].min()
# Out:
# '1'

# %% [markdown]
# ### Show Movies Which are Comedies OR Show TV Shows Which are Kids' TV

# %%
ds[(ds["type"] == "Movie") & (ds["listed_in"] == "Comedies")]
# Out:
#      show_id   type                                      title  \
# 16      s913  Movie                The Circle - The Afterparty
# 31       s28  Movie                                  Grown Ups
# 184    s1029  Movie  Dad Stop Embarrassing Me - The Afterparty
# 186     s153  Movie              Janoskians: Untold and Untrue
# 254     s183  Movie                Welcome Home Roscoe Jenkins
# ...      ...    ...                                        ...
# 6825   s1158  Movie                                   Bad Trip
# 7611   s3630  Movie                                  Otherhood
# 7698   s3828  Movie        Still LAUGH-IN: The Stars Celebrate
# 7958   s4696  Movie      Party Monster: Scratching the Surface
# 7977   s4762  Movie                         Father of the Year
#
#                              director         country date_added  \
# 16    Krysia Plonka, Kristian Mercado   United States   5/7/2021
# 31                       Dennis Dugan   United States  9/20/2021
# ...

# %%
ds[(ds["type"] == "TV Show") & (ds["listed_in"] == "Kids' TV")]
# Out:
#      show_id     type                              title  \
# 20     s4832  TV Show              True: Magical Friends
# 21     s4833  TV Show             True: Wonderful Wishes
# 22     s4857  TV Show             Dance & Sing with True
# 37       s35  TV Show            Tayo and Little Wizards
# 42       s90  TV Show                        Mighty Raju
# ...      ...      ...                                ...
# 8744   s8524  TV Show  The Super Mario Bros. Super Show!
# 8757   s8597  TV Show                      Tip the Mouse
# 8766   s8670  TV Show                      V.R. Troopers
# 8789   s8784  TV Show                               Yoko
# 8790   s8786  TV Show                                YOM
#
#                           director        country date_added  release_year  \
# 20    Mark Thornton, Todd Kauffman  United States  6/15/2018        2018.0
# 21    Mark Thornton, Todd Kauffman  United States  6/15/2018        2018.0
# ...

# %%
ds[(ds["type"] == "Movie") & (ds["listed_in"] == "Comedies") | (ds["type"] == "TV Show") & (ds["listed_in"] == "Kids' TV")]
# Out:
#      show_id     type                              title  \
# 16      s913    Movie        The Circle - The Afterparty
# 20     s4832  TV Show              True: Magical Friends
# 21     s4833  TV Show             True: Wonderful Wishes
# 22     s4857  TV Show             Dance & Sing with True
# 31       s28    Movie                          Grown Ups
# ...      ...      ...                                ...
# 8744   s8524  TV Show  The Super Mario Bros. Super Show!
# 8757   s8597  TV Show                      Tip the Mouse
# 8766   s8670  TV Show                      V.R. Troopers
# 8789   s8784  TV Show                               Yoko
# 8790   s8786  TV Show                                YOM
#
#                              director        country date_added  release_year  \
# 16    Krysia Plonka, Kristian Mercado  United States   5/7/2021        2021.0
# 20       Mark Thornton, Todd Kauffman  United States  6/15/2018        2018.0
# ...

# %% [markdown]
# ### Which Country Has The Highest Number Of Movies On Netflix

# %%
ds.head(3)
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration  \
# 0  9/25/2021        2020.0  PG-13    90 min
# 1  9/24/2021        2021.0  TV-MA  1 Season
# 2  9/24/2021        2021.0  TV-MA  1 Season
#
#                                            listed_in  release_y   years  \
# 0                                      Documentaries 2021-09-25  2021.0
# 1  Crime TV Shows, International TV Shows, TV Act... 2021-09-24  2021.0
# 2                 TV Dramas, TV Horror, TV Mysteries 2021-09-24  2021.0
#
#   Minute    Unit
# 0     90     min
# 1      1  Season
# 2      1  Season

# %%
ds_movie=ds[ds["type"] == "Movie"]

# %%
ds_movie
# Out:
#      show_id   type                             title             director  \
# 0         s1  Movie              Dick Johnson Is Dead      Kirsten Johnson
# 3        s14  Movie  Confessions of an Invisible Girl        Bruno Garotti
# 6        s10  Movie                      The Starling       Theodore Melfi
# 7       s939  Movie   Motu Patlu in the Game of Zones          Suhas Kadav
# 8        s13  Movie                      Je Suis Karl  Christian Schwochow
# ...      ...    ...                               ...                  ...
# 8703   s8232  Movie                          The Bund            Not Given
# 8708   s8269  Movie                  The Darkest Dawn            Not Given
# 8717   s8331  Movie                  The Great Battle            Not Given
# 8764   s8648  Movie       Twisted Trunk, Big Fat Body            Not Given
# 8784   s8785  Movie              Yoko and His Friends            Not Given
#
#              country date_added  release_year rating duration  \
# ...

# %%
ds_movie.country.value_counts()
# Out:
# country
# United States     2388
# India              975
# United Kingdom     386
# Not Given          257
# Canada             187
#                   ...
# Zimbabwe             1
# Mozambique           1
# Namibia              1
# Cameroon             1
# Croatia              1
# Name: count, Length: 78, dtype: int64

# %%
ds_movie.country.value_counts().head(10).plot(kind="bar",color=['b','y','g','r','k','y','gray','orange','g','y'])
# Out:
# <Axes: xlabel='country'>

# %% [markdown]
# ### Show That How Many Movies And TV shows On Netflix Released By Pakistan

# %%
pakistan_records = ds[ds['country'] == 'Pakistan']

# %%
pakistan_type_counts = pakistan_records.groupby('type').type.count()

# %%
pakistan_type_counts
# Out:
# type
# Movie       71
# TV Show    346
# Name: type, dtype: int64

# %%
pakistan_type_counts.plot(kind="pie", colors=['gray','y'])
# Out:
# <Axes: ylabel='type'>
